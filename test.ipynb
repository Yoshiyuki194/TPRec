# %%
import pandas as pd

# %%
embeds = pd.read_pickle('./tmp/Amazon_Cellphones/init_embedding/transe_embed.pkl')

# %%
after_embeds = pd.read_pickle('./tmp/Amazon_Cellphones/transe_embed.pkl')

# %%
embeds
# Out:
# {'user': array([[-1.0626117e+00, -6.2540554e-02, -2.3639994e-03, ...,
#           3.5560367e-01, -1.7820194e-01, -4.0874007e-01],
#         [ 2.2297740e-01, -1.5998541e-01, -1.7388605e-02, ...,
#          -2.9901701e-01,  6.4223431e-02,  4.4793159e-01],
#         [ 2.5455636e-01, -9.8177090e-02,  5.0162397e-02, ...,
#          -4.7011310e-01,  2.5093639e-01,  5.4473823e-01],
#         ...,
#         [ 5.2235186e-02, -5.4963940e-01,  3.6526830e-03, ...,
#          -1.4172833e-02, -3.3667678e-01,  3.8454235e-01],
#         [-1.7493394e-01,  4.4229689e-01, -6.9389951e-01, ...,
#           5.7922584e-01, -7.5865227e-01, -3.0982209e-02],
#         [-1.7477816e-03,  4.3045729e-03,  7.7309832e-04, ...,
#           2.5842623e-03,  8.3597936e-04, -4.2681890e-03]], dtype=float32),
#  'product': array([[ 0.6042223 ,  0.2189927 ,  0.19511384, ...,  0.5435165 ,
#           0.77366596, -0.3430255 ],
#         [ 0.19885828,  0.07415991,  0.8043244 , ...,  0.24390061,
# ...
